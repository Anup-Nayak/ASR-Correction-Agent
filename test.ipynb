# %%
output = [
    "SHE FORMED AMONG THE FLICKERING SHADOWS A GRACEFUL AND HARMONIOUS IMAGE",
    "AND WHO FROM A PRIVATE STATION HAD MOUNTED IN THE EARLIEST YOUTH",
    "I CAN'T SAY WHETHER THERE IS A WILL OR NOT LET US TALK OF SOMETHING ELSE",
    "WHICH MOST FREQUENTLY CAN BE TRACED BACK TO THE UNBOUNDED EGOISM OF THE DREAMER",
    "AND THAT FRESH HEARER WAS MARTIN POYSER WHO AS HIS WIFE SAID",
    "HESITATION WHAT DO YOU KNOW ASKED OLD MOTHER NATURE HESITATION",
    "MISTER FRANK CHURCHILL WAS ONE OF THE BOASTS OF HIGHBURY AND A LIVELY CURIOSITY TO SEE HIM PREVAILED",
    "SO THAT THE WATERS WERE MADE TO STAND FIRM AS A WALL ON EITHER SIDE",
    "THE MERCHANT BEING RECOVERED FROM HIS TERROR MOUNTED HIS HORSE AND PROCEEDED ON HIS JOURNEY",
    "CHANNEL I DARESAY ONE WOULD BE ALLOWED TO SEE OVER THE HOUSIE CHANNEL",
    "TAKING A FINAL SPURT DOWN TO A FERRY LANDING A QUARTER OF A MILE BEYOND ON THE SOUTH BANK",
    "ITALIANS ALL READY THEY ANSWERED AND THE LIEUTENANT LED THE WAY TO THE TRAIN",
    "AND SHE CAME YET HALTING FROM HER RECENT WOUND TAKE HER SAYS PLUTO AND LEAD HER BACK TO THE LIGHT",
    "WITH LOUD ACCLAMATIONS CRIED OUT VICTORY VICTORY IN FAVOUR OF THE CHAMPION IN WHITE",
    "OH IT'S AT THE REHEARSALS YOU KNOW THAT THE FUN IS",
    "DAUPHINES WITHOUT A RIGHT OR WRONG SIDE IN THE PIECE",
    "NOT THAT I THINK CHARLOTTE SO VERY PLAIN BUT THEN SHE IS OUR PARTICULAR FRIEND",
    "AND THEN COMES MURDER CREEK WHICH TAKES YOU ON TO TARRANGOWER",
    "TURNING AWAY TOWARD THE GREEN MEADOWS INSTEAD PETER DIDN'T WAIT FOR SCRAPPER TO RETURN",
    "HE LEFT SO AS TO SEEK AFTER BERNARD SAID LUCY QUICKLY MISTER DURHAM TOLD ME SO",
    "THE TONES THE LOOKS THAT HAD ACCOMPANIED THOSE WORDS BUT ALL SHE SAID WAS I DIDN'T THINK TO SEE YO",
    "AT THE SAME TIME AS THE MOUTH BETWEEN THE WHEELS A HEAD WAS PUT THROUGH THE WINDOW",
    "THEY ARE A SMALLER HORDE THAN THE THARKS BUT MUCH MORE FEROCIOUS",
    "WHICH IN THESE PEACEFUL TIMES IS FOR ME A SUFFICIENTLY PLEASING PICTURE OF WAR ON A SMALL SCALE",
    "AND THEN TO BANISH US OUT OF SYRIA FOR EVER BUT HOW UNWORTHY SOEVER OUR USAGE HAS BEEN",
    "THE THORN GROWS WITH THE ROSE THE POISON TREE AND THE CINNAMON MINGLE THEIR BOUGHS",
    "HOW THE FATHER DOTED ON THE SMILES OF THE INFANT",
    "ARE THE GOLDEN AGE AND DREAM DAYS AM I NOT RIGHT THANK YOU BUT THE BOOK YOU HAVE NOT READ MY BOOK",
    "THE DURATION IN OFFICE OF THE EXECUTIVE FROM THE NEW YORK PACKET",
    "IS THE CHILD OF YOUR THOUGHT",
    "AND IF HE DOESN'T LISTEN TO MY ADVICE I AM GOING TO MAKE IT AS UNPLEASANT AS I CAN PRESIDENT WILSON",
    "THERE WAS GOOD REASON TO STOP AND THINK EVEN FOR THE WORLD'S MOST EMOTIONLESS MAN",
    "GLADLY WILL I DO SO ANSWERED PERCEVAL SO THEY WENT TOGETHER TO ARTHUR AND SALUTED HIM",
    "ME THEY STRIPPED LIKE A SLAVE THEY LED ME THROUGH THE CITY AND THE PEOPLE MOCKED ME",
    "AND EVEN MORE CONTEMPTIBLE THAN THAT IS MY MAKING THIS REMARK NOW BUT THAT'S ENOUGH",
    "WORTHY FOSTER FATHER WELL WELL",
    "THE THIRD MAN FROM THE END OH PATTY DID YOU BRING US SOME WEDDING CAKE DID YOU HAVE ANY ADVENTURES",
    "SEVERAL PIPES THAT HAD BEEN EXTINGUISHED WERE LIGHTED AGAIN",
    "HESITATION TO A THIRTH THE EAST TO A FOURTH THE WEST",
    "THE OLD MAN HAD IN THE MEANTIME BEEN PENSIVE BUT ON THE APPEARANCE OF HIS COMPANIONS",
    "THE YOUNG WOMAN WHEN SHE OPENED THE DOOR IN THE MORNING",
    "AYE AND FOUND IT LIGHTER TOO SOME DAY FOR SURELY SURELY THIS IS NOT THE END",
    "WHICH WILL PREVENT YOU FROM BEING BURNED UP AND CURE YOU IF YOU CHANCE TO BE A LITTLE SCORCHED",
    "I WAS ENTIRELY WITHOUT FRIENDS NAY EVEN SO MUCH AS WITHOUT ACQUAINTANCE",
    "HE MOVED A LITTLE AND SUDDENLY THERE WAS A RINGING IN HIS EARS",
    "ONE WOULD DROP INTO THE BOAT WE SOON DISCOVERED SOME INDIANS FOLLOWING THE SCHOOL",
    "OUTWARD FORMS AND SYMBOLS MUST BE USED TO CONVEY INTELLECTUAL CONCEPTIONS",
    "TURNING TO HIS SECRETARY OF STATE HE SAID TO EXPLAIN HIS HESITATION",
    "LAWYER WATSON AND UNCLE JOHN WERE THERE LOOKING AS GRAVE AS THE IMPORTANT OCCASION DEMANDED",
    "SHALMANESER THE THIRD OF ASSYRIA FOUND IT NECESSARY TO INVADE BABYLONIA",
    "TWENTIETH ROW SEAMED MAKE ONE AT THE BEGINNING TWENTY FIRST ROW SAME AS ELEVENTH",
    "BEYOND THE SOUTHERN BOUNDARY OF THE TERRITORY GASHED BY STUPENDOUS CANYONS",
    "WITHIN A FEW MINUTES THEIR RUNNING FOOTSTEPS HAD DIED AWAY IN THE DISTANCE",
    "FETNAH THEN SAID LET US BLESS HEAVEN FOR HAVING BROUGHT US ALL TOGETHER",
    "RUSSEN AND FAIR PULLING LYON RILEY CHESHIRE AND LESLY WITH MUSKETS AND JOHN REX IN THE STERN SHEETS",
    "LOOKED AWAY AS SOON AS POSSIBLE",
    "MARIANNE LOOKED WITH AMAZEMENT AT EDWARD WITH COMPASSION AT HER SISTER",
    "SURELY LUCK HAS BROUGHT US ALSO TO A NEW COUNTRY",
    "INVINCIBLE JEALOUSY AND HATE INVOLUNTARY THRILL OF GRATIFIED VANITY INVOLVED IN PROFOUND UNCERTAINTY",
    "OTHERS WISH HIM TO BE CHOSEN BY THE DECEASED OR ASSUMED BY THE LAW TO BE SO CHOSEN",
    "STOCKINGS HAD TO BE DRAWN OFF VIOLENTLY BY ANOTHER PERSON",
    "THOUGH THERE'S SOME ON IT AS ONE'S NO NEED TO SEE THE SMELL'S ENOUGH",
    "SERVING AS A SAFE DEPOSITORY OF THE ARTICLES MENTIONED TO DANTES",
    "CARBINEER IF THE SAME TO YOU MASTER SAID THE OTHER QUIETLY I NEVER SERVED IN THE INFANTRY",
    "JACKSON WHAT TIME DID MISTER WOODS GET OUT HERE ON THE EVENING MISTER FELDERSON WAS KILLED",
    "CHAMBERS WHICH ON ONE MELANCHOLY OCCASION DID BECOME ABSOLUTELY SUICIDAL",
    "NEITHER HER FATHER NOR MISTER ALLEN DID SO IT WAS CERTAINLY VERY PROVOKING",
    "SKELETONS THEY WERE AND NO HUMAN BEINGS AT ALL HER FATHER",
    "EXPOSING THE CROWN ALTHOUGH THEIR CONCORD HAD ONLY EVIL AS ITS RESULT",
    "RETURN'D WITH A HEART OVERWHELM'D WITH DESPAIR TO THE COURT OF BABYLON",
    "TENAYA INQUIRED WHAT WAS THE OBJECT OF TAKING ALL THE INDIANS TO THE SAN JOAQUIN PLAIN MY PEOPLE"
  ]

# %%
answer = [
  "SHE FORMED AMONG THE FLICKERING SHADOWS A GRACEFUL AND HARMONIOUS IMAGE",
  "AND WHO FROM A PRIVATE STATION HAD MOUNTED IN THE EARLIEST YOUTH",
  "I CAN'T SAY WHETHER THERE IS A WILL OR NOT LET US TALK OF SOMETHING ELSE",
  "WHICH MOST FREQUENTLY CAN BE TRACED BACK TO THE UNBOUNDED EGOISM OF THE DREAMER",
  "AND THAT FRESH HEARER WAS MARTIN POYSER WHO AS HIS WIFE SAID",
  "WHAT DO YOU KNOW ASKED OLD MOTHER NATURE",
  "MISTER FRANK CHURCHILL WAS ONE OF THE BOASTS OF HIGHBURY AND A LIVELY CURIOSITY TO SEE HIM PREVAILED",
  "SO THAT THE WATERS WERE MADE TO STAND FIRM AS A WALL ON EITHER SIDE",
  "THE MERCHANT BEING RECOVERED FROM HIS TERROR MOUNTED HIS HORSE AND PROCEEDED ON HIS JOURNEY",
  "I DARESAY ONE WOULD BE ALLOWED TO SEE OVER THE HOUSE",
  "TAKING A FINAL SPURT DOWN TO A FERRY LANDING A QUARTER OF A MILE BEYOND ON THE SOUTH BANK",
  "ALL READY THEY ANSWERED AND THE LIEUTENANT LED THE WAY TO THE TRAIN",
  "AND SHE CAME YET HALTING FROM HER RECENT WOUND TAKE HER SAYS PLUTO AND LEAD HER BACK TO THE LIGHT",
  "WITH LOUD ACCLAMATIONS CRIED OUT VICTORY VICTORY IN FAVOUR OF THE CHAMPION IN WHITE",
  "OH IT'S AT THE REHEARSALS YOU KNOW THAT THE FUN IS",
  "DAUPHINES WITHOUT A RIGHT OR WRONG SIDE IN THE PIECE",
  "NOT THAT I THINK CHARLOTTE SO VERY PLAIN BUT THEN SHE IS OUR PARTICULAR FRIEND",
  "AND THEN COMES MURDER CREEK WHICH TAKES YOU ON TO TARRANGOWER",
  "TURNING AWAY TOWARD THE GREEN MEADOWS INSTEAD PETER DIDN'T WAIT FOR SCRAPPER TO RETURN",
  "HE LEFT SO AS TO SEEK AFTER BERNARD SAID LUCY QUICKLY MISTER DURHAM TOLD ME SO",
  "THE TONES THE LOOKS THAT HAD ACCOMPANIED THOSE WORDS BUT ALL SHE SAID WAS I DIDN'T THINK TO SEE YO",
  "AT THE SAME TIME AS THE MOUTH BETWEEN THE WHEELS A HEAD WAS PUT THROUGH THE WINDOW",
  "THEY ARE A SMALLER HORDE THAN THE THARKS BUT MUCH MORE FEROCIOUS",
  "WHICH IN THESE PEACEFUL TIMES IS FOR ME A SUFFICIENTLY PLEASING PICTURE OF WAR ON A SMALL SCALE",
  "AND THEN TO BANISH US OUT OF SYRIA FOR EVER BUT HOW UNWORTHY SOEVER OUR USAGE HAS BEEN",
  "THE THORN GROWS WITH THE ROSE THE POISON TREE AND THE CINNAMON MINGLE THEIR BOUGHS",
  "HOW THE FATHER DOTED ON THE SMILES OF THE INFANT",
  "ARE THE GOLDEN AGE AND DREAM DAYS AM I NOT RIGHT THANK YOU BUT THE BOOK YOU HAVE NOT READ MY BOOK",
  "THE DURATION IN OFFICE OF THE EXECUTIVE FROM THE NEW YORK PACKET",
  "IS THE CHILD OF YOUR THOUGHT",
  "AND IF HE DOESN'T LISTEN TO MY ADVICE I AM GOING TO MAKE IT AS UNPLEASANT AS I CAN PRESIDENT WILSON",
  "THERE WAS GOOD REASON TO STOP AND THINK EVEN FOR THE WORLD'S MOST EMOTIONLESS MAN",
  "GLADLY WILL I DO SO ANSWERED PERCEVAL SO THEY WENT TOGETHER TO ARTHUR AND SALUTED HIM",
  "ME THEY STRIPPED LIKE A SLAVE THEY LED ME THROUGH THE CITY AND THE PEOPLE MOCKED ME",
  "AND EVEN MORE CONTEMPTIBLE THAN THAT IS MY MAKING THIS REMARK NOW BUT THAT'S ENOUGH",
  "WORTHY FOSTER FATHER WELL WELL",
  "THE THIRD MAN FROM THE END OH PATTY DID YOU BRING US SOME WEDDING CAKE DID YOU HAVE ANY ADVENTURES",
  "SEVERAL PIPES THAT HAD BEEN EXTINGUISHED WERE LIGHTED AGAIN",
  "TO A THIRD THE EAST TO A FOURTH THE WEST",
  "THE OLD MAN HAD IN THE MEANTIME BEEN PENSIVE BUT ON THE APPEARANCE OF HIS COMPANIONS",
  "THE YOUNG WOMAN WHEN SHE OPENED THE DOOR IN THE MORNING",
  "AYE AND FOUND IT LIGHTER TOO SOME DAY FOR SURELY SURELY THIS IS NOT THE END",
  "WHICH WILL PREVENT YOU FROM BEING BURNED UP AND CURE YOU IF YOU CHANCE TO BE A LITTLE SCORCHED",
  "I WAS ENTIRELY WITHOUT FRIENDS NAY EVEN SO MUCH AS WITHOUT ACQUAINTANCE",
  "HE MOVED A LITTLE AND SUDDENLY THERE WAS A RINGING IN HIS EARS",
  "ONE WOULD DROP INTO THE BOAT WE SOON DISCOVERED SOME INDIANS FOLLOWING THE SCHOOL",
  "OUTWARD FORMS AND SYMBOLS MUST BE USED TO CONVEY INTELLECTUAL CONCEPTIONS",
  "TURNING TO HIS SECRETARY OF STATE HE SAID TO EXPLAIN HIS HESITATION",
  "LAWYER WATSON AND UNCLE JOHN WERE THERE LOOKING AS GRAVE AS THE IMPORTANT OCCASION DEMANDED",
  "SHALMANESER THE THIRD OF ASSYRIA FOUND IT NECESSARY TO INVADE BABYLONIA",
  "TWENTIETH ROW SEAMED MAKE ONE AT THE BEGINNING TWENTY FIRST ROW SAME AS ELEVENTH",
  "BEYOND THE SOUTHERN BOUNDARY OF THE TERRITORY GASHED BY STUPENDOUS CANYONS",
  "WITHIN A FEW MINUTES THEIR RUNNING FOOTSTEPS HAD DIED AWAY IN THE DISTANCE",
  "FETNAH THEN SAID LET US BLESS HEAVEN FOR HAVING BROUGHT US ALL TOGETHER",
  "RUSSEN AND FAIR PULLING LYON RILEY CHESHIRE AND LESLY WITH MUSKETS AND JOHN REX IN THE STERN SHEETS",
  "LOOKED AWAY AS SOON AS POSSIBLE",
  "MARIANNE LOOKED WITH AMAZEMENT AT EDWARD WITH COMPASSION AT HER SISTER",
  "SURELY LUCK HAS BROUGHT US ALSO TO A NEW COUNTRY",
  "INVINCIBLE JEALOUSY AND HATE INVOLUNTARY THRILL OF GRATIFIED VANITY INVOLVED IN PROFOUND UNCERTAINTY",
  "OTHERS WISH HIM TO BE CHOSEN BY THE DECEASED OR ASSUMED BY THE LAW TO BE SO CHOSEN",
  "STOCKINGS HAD TO BE DRAWN OFF VIOLENTLY BY ANOTHER PERSON",
  "THOUGH THERE'S SOME ON IT AS ONE'S NO NEED TO SEE THE SMELL'S ENOUGH",
  "SERVING AS A SAFE DEPOSITORY OF THE ARTICLES MENTIONED TO DANTES",
  "CARBINEER IF THE SAME TO YOU MASTER SAID THE OTHER QUIETLY I NEVER SERVED IN THE INFANTRY",
  "JACKSON WHAT TIME DID MISTER WOODS GET OUT HERE ON THE EVENING MISTER FELDERSON WAS KILLED",
  "CHAMBERS WHICH ON ONE MELANCHOLY OCCASION DID BECOME ABSOLUTELY SUICIDAL",
  "NEITHER HER FATHER NOR MISTER ALLEN DID SO IT WAS CERTAINLY VERY PROVOKING",
  "SKELETONS THEY WERE AND NO HUMAN BEINGS AT ALL HER FATHER",
  "EXPOSING THE CROWN ALTHOUGH THEIR CONCORD HAD ONLY EVIL AS ITS RESULT",
  "RETURN'D WITH A HEART OVERWHELM'D WITH DESPAIR TO THE COURT OF BABYLON",
  "TENAYA INQUIRED WHAT WAS THE OBJECT OF TAKING ALL THE INDIANS TO THE SAN JOAQUIN PLAIN MY PEOPLE"
]

# %%
count = 0
for i in range(len(answer)):
    if answer[i] != output[i]:
        print(i+1)
        print(output[i])
        print(answer[i])
        print("")
        count += 1
print(count)
# Out:
# 6
# HESITATION WHAT DO YOU KNOW ASKED OLD MOTHER NATURE HESITATION
# WHAT DO YOU KNOW ASKED OLD MOTHER NATURE
#
# 10
# CHANNEL I DARESAY ONE WOULD BE ALLOWED TO SEE OVER THE HOUSIE CHANNEL
# I DARESAY ONE WOULD BE ALLOWED TO SEE OVER THE HOUSE
#
# 12
# ITALIANS ALL READY THEY ANSWERED AND THE LIEUTENANT LED THE WAY TO THE TRAIN
# ALL READY THEY ANSWERED AND THE LIEUTENANT LED THE WAY TO THE TRAIN
#
# 39
# HESITATION TO A THIRTH THE EAST TO A FOURTH THE WEST
# TO A THIRD THE EAST TO A FOURTH THE WEST
#
# 4

# %%
import pickle

with open('data/data.pkl','rb') as f:
    data = pickle.load(f)
    
data
# Out:
# [{'audio': {'array': array([ 0.01193237,  0.00387573, -0.00817871, ...,  0.00112915,
#            0.00131226,  0.00143433]),
#    'sampling_rate': 16000},
#   'gold': 'SHE FORMED AMONG THE FLICKERING SHADOWS A GRACEFUL AND HARMONIOUS IMAGE',
#   'text': 'SHE FOLBED AMONG TE FLICKEWING SHADOWS A GRACEFUL AND HARMONIOUS IMAGE'},
#  {'audio': {'array': array([ 3.26538086e-03,  4.48608398e-03, -2.92968750e-03, ...,
#            9.15527344e-05,  1.55639648e-03,  1.58691406e-03]),
#    'sampling_rate': 16000},
#   'gold': 'AND WHO FROM A PRIVATE STATION HAD MOUNTED IN THE EARLIEST YOUTH',
#   'text': 'AND WHO FLOB A PRIVATE STATION HAD MOUNTED IN THE EARLIEST YOUTH'},
#  {'audio': {'array': array([ 0.00170898,  0.00061035,  0.00039673, ..., -0.00030518,
#           -0.00030518, -0.00024414]),
#    'sampling_rate': 16000},
#   'gold': "I CAN'T SAY WHETHER THERE IS A WILL OR NOT LET US TALK OF SOMETHING ELSE",
#   'text': "I CAN'T ZAY WHEDER THERE IS A WILL OR NOT LET UZ TALK OF SOMEDING ELSE"},
#  {'audio': {'array': array([ 1.34277344e-03,  1.19018555e-03,  0.00000000e+00, ...,
#           -3.35693359e-04, -9.15527344e-05,  1.22070312e-04]),
#    'sampling_rate': 16000},
#   'gold': 'WHICH MOST FREQUENTLY CAN BE TRACED BACK TO THE UNBOUNDED EGOISM OF THE DREAMER',
#   'text': 'WHICH MOZT FLEQUENTLY CAN BE TRACED BACK TO THE UNBOUNDED EGOISM OF DE DREAMER'},
#  {'audio': {'array': array([-0.00292969, -0.00286865, -0.00378418, ...,  0.0038147 ,
#            0.00418091,  0.00518799]),
#    'sampling_rate': 16000},
#   'gold': 'AND THAT FRESH HEARER WAS MARTIN POYSER WHO AS HIS WIFE SAID',
#   'text': 'AND THAT FLES HEAREL WAS NARTIN POYSER WHO AS HIS WIFE SAID'},
#  {'audio': {'array': array([-0.10998535, -0.11044312, -0.1105957 , ..., -0.11990356,
#           -0.11999512, -0.11959839]),
#    'sampling_rate': 16000},
#   'gold': 'WHAT DO YOU KNOW ASKED OLD MOTHER NATURE',
#   'text': 'WHAT DO YOU KNOW ASKED OLD MOTHEW NATURE'},
#  {'audio': {'array': array([ 0.00149536,  0.00152588,  0.00100708, ..., -0.00827026,
#           -0.00106812,  0.0012207 ]),
#    'sampling_rate': 16000},
#   'gold': 'MISTER FRANK CHURCHILL WAS ONE OF THE BOASTS OF HIGHBURY AND A LIVELY CURIOSITY TO SEE HIM PREVAILED',
#   'text': 'MISTER FRANK CHUWCHILL WAS ONE OF THE BOASTS OF HIGHBURY AND A LIVELY CUWIOZITY TO SEE HIM PLEVELED'},
#  {'audio': {'array': array([ 7.32421875e-04,  9.15527344e-04,  1.37329102e-03, ...,
#            1.22070312e-04, -9.15527344e-05,  1.83105469e-04]),
#    'sampling_rate': 16000},
#   'gold': 'SO THAT THE WATERS WERE MADE TO STAND FIRM AS A WALL ON EITHER SIDE',
#   'text': 'SO THAT THE WATEWS WERE MADE TO SHTAND FIWB AS A WALL ON EITHER SIDE'},
#  {'audio': {'array': array([ 0.00265503,  0.00219727,  0.0020752 , ..., -0.00491333,
#           -0.00341797, -0.00326538]),
#    'sampling_rate': 16000},
#   'gold': 'THE MERCHANT BEING RECOVERED FROM HIS TERROR MOUNTED HIS HORSE AND PROCEEDED ON HIS JOURNEY',
#   'text': 'FE MERCHANT BEING RECOVERED FROM HIS TERROR MOUNTED HIS HOWSHE AND PROCEEDED ON HIS GOURNEY'},
#  {'audio': {'array': array([-5.49316406e-04, -1.52587891e-03, -2.13623047e-03, ...,
#           -8.54492188e-04,  9.15527344e-05, -6.10351562e-05]),
#    'sampling_rate': 16000},
#   'gold': 'I DARESAY ONE WOULD BE ALLOWED TO SEE OVER THE HOUSE',
#   'text': 'I DARESAY ONE WOULD BE ALLOWED TO SHEE OVER TE HOUSE'},
#  {'audio': {'array': array([0., 0., 0., ..., 0., 0., 0.]),
#    'sampling_rate': 16000},
#   'gold': 'TAKING A FINAL SPURT DOWN TO A FERRY LANDING A QUARTER OF A MILE BEYOND ON THE SOUTH BANK',
#   'text': 'TAKING A FINAL SPULT DOWN TO A FELWY LANDING A QUALTER OF A BILE BEYOND ON THE SOUTH BANK'},
#  {'audio': {'array': array([-1.61743164e-03, -1.37329102e-03, -9.76562500e-04, ...,
#           -9.15527344e-05, -3.05175781e-05, -1.52587891e-04]),
#    'sampling_rate': 16000},
#   'gold': 'ALL READY THEY ANSWERED AND THE LIEUTENANT LED THE WAY TO THE TRAIN',
#   'text': 'ALL READY THEY ANSWERED AND THE LIOTENANT LED FE WAY TO THE TLAIN'},
#  {'audio': {'array': array([ 3.05175781e-05, -2.44140625e-04, -3.96728516e-04, ...,
#           -3.96728516e-04, -2.74658203e-04, -9.15527344e-05]),
#    'sampling_rate': 16000},
#   'gold': 'AND SHE CAME YET HALTING FROM HER RECENT WOUND TAKE HER SAYS PLUTO AND LEAD HER BACK TO THE LIGHT',
#   'text': 'AND SHE CAME YET HALTING FLOM HER RECENT WOUND TAKE HER SAYS PLUTO AND LEAD HEL BACK TO THE LIGHT'},
#  {'audio': {'array': array([ 0.00030518,  0.00021362, -0.00048828, ..., -0.00033569,
#           -0.00131226, -0.00259399]),
#    'sampling_rate': 16000},
#   'gold': 'WITH LOUD ACCLAMATIONS CRIED OUT VICTORY VICTORY IN FAVOUR OF THE CHAMPION IN WHITE',
#   'text': 'WID LOUD ACCLAMATIONS CLIED OUT VICTORY VICTOLY IN FAVOUR OF THE CHAMPION IN WHITE'},
#  {'audio': {'array': array([0.0010376 , 0.0010376 , 0.00131226, ..., 0.00643921, 0.00598145,
#           0.00552368]),
#    'sampling_rate': 16000},
#   'gold': "OH IT'S AT THE REHEARSALS YOU KNOW THAT THE FUN IS",
#   'text': "OH IT'S AT THE REHEARSALS YOU KNOW THAT FE FUN IS"},
#  {'audio': {'array': array([-0.00152588,  0.00259399,  0.00375366, ..., -0.00094604,
#           -0.00021362,  0.00079346]),
#    'sampling_rate': 16000},
#   'gold': 'DAUPHINES WITHOUT A RIGHT OR WRONG SIDE IN THE PIECE',
#   'text': 'DAUPHINES WITHOUT A RIGHT OR WRONG SIDE IN TE PIECE'},
#  {'audio': {'array': array([ 0.00054932, -0.00015259,  0.00033569, ..., -0.00076294,
#           -0.00091553, -0.00131226]),
#    'sampling_rate': 16000},
#   'gold': 'NOT THAT I THINK CHARLOTTE SO VERY PLAIN BUT THEN SHE IS OUR PARTICULAR FRIEND',
#   'text': 'NOT DAT I THINK CHARLOTTE SO VERY PLAIN BUT THEN CHE IS OUR PAWTICULAR FRIEND'},
#  {'audio': {'array': array([-0.02770996, -0.02893066, -0.02896118, ..., -0.0050354 ,
#           -0.00552368, -0.00509644]),
#    'sampling_rate': 16000},
#   'gold': 'AND THEN COMES MURDER CREEK WHICH TAKES YOU ON TO TARRANGOWER',
#   'text': 'AND FEN COMEZ MURDEW CLEEK WHICH TAKES YOU ON TO TARRANGOWER'},
#  {'audio': {'array': array([-0.00283813, -0.00396729, -0.00357056, ...,  0.00274658,
#            0.00271606,  0.00234985]),
#    'sampling_rate': 16000},
#   'gold': "TURNING AWAY TOWARD THE GREEN MEADOWS INSTEAD PETER DIDN'T WAIT FOR SCRAPPER TO RETURN",
#   'text': "TULNING AWAY TOWARD THE GREEN MEADOWSH INSTEAD PETER DIDN'T WAIT FOR ZCRAPPEL TO RETURN"},
#  {'audio': {'array': array([ 2.74658203e-04, -6.10351562e-05,  6.10351562e-05, ...,
#           -3.05175781e-04, -4.88281250e-04, -3.96728516e-04]),
#    'sampling_rate': 16000},
#   'gold': 'HE LEFT SO AS TO SEEK AFTER BERNARD SAID LUCY QUICKLY MISTER DURHAM TOLD ME SO',
#   'text': 'HE LEFT SO AS TO SEEK AFTEL BERNARD SID LUCY QUICKLY MISTER DUWHAM TOLD NE SO'},
#  {'audio': {'array': array([0.        , 0.        , 0.        , ..., 0.00088501, 0.00085449,
#           0.00085449]),
#    'sampling_rate': 16000},
#   'gold': "THE TONES THE LOOKS THAT HAD ACCOMPANIED THOSE WORDS BUT ALL SHE SAID WAS I DIDN'T THINK TO SEE YO",
#   'text': "THE TONEZ THE LOOKS THAT HAD ACCOMPANAD THOSHE WORDZ BUT ALL SHE SHAID WASH I DIDN'T THINK TO SEE YO"},
#  {'audio': {'array': array([-0.00018311, -0.00024414, -0.00027466, ...,  0.00048828,
#            0.0007019 ,  0.00048828]),
#    'sampling_rate': 16000},
#   'gold': 'AT THE SAME TIME AS THE MOUTH BETWEEN THE WHEELS A HEAD WAS PUT THROUGH THE WINDOW',
#   'text': 'AT THE SABE TIME AS THE MOUTH BETWEEN THE WHEELZ A HEAD WAS PUT DROUGH THE WINDOW'},
#  {'audio': {'array': array([ 0.0012207 ,  0.00262451, -0.00204468, ..., -0.00033569,
#           -0.00076294, -0.00085449]),
#    'sampling_rate': 16000},
#   'gold': 'THEY ARE A SMALLER HORDE THAN THE THARKS BUT MUCH MORE FEROCIOUS',
#   'text': 'THEY AWE A SMALLER HOWDE THAN THE THARCZ BUT MUCH MORE FEROCIOUS'},
#  {'audio': {'array': array([-0.00180054, -0.0022583 , -0.00161743, ...,  0.00494385,
#            0.00500488,  0.00482178]),
#    'sampling_rate': 16000},
#   'gold': 'WHICH IN THESE PEACEFUL TIMES IS FOR ME A SUFFICIENTLY PLEASING PICTURE OF WAR ON A SMALL SCALE',
#   'text': 'WHICH IN TESE PEACEFUL TINESH IS FOR ME A SUFFICIENTLY PLEASHING PICTUWE OF WAL ON A SMALL SCALE'},
#  {'audio': {'array': array([-0.00314331, -0.00271606, -0.00537109, ..., -0.0020752 ,
#           -0.00137329, -0.00061035]),
#    'sampling_rate': 16000},
#   'gold': 'AND THEN TO BANISH US OUT OF SYRIA FOR EVER BUT HOW UNWORTHY SOEVER OUR USAGE HAS BEEN',
#   'text': 'AND THEN TO BANISH US OUT OF ZYRIA FOW EVEW BUT HOW UNWORTHY SOEVER OUR USAGE HAZ BEEN'},
#  {'audio': {'array': array([-9.76562500e-04, -3.66210938e-04, -6.10351562e-05, ...,
#           -1.64794922e-03,  3.05175781e-05,  8.85009766e-04]),
#    'sampling_rate': 16000},
#   'gold': 'THE THORN GROWS WITH THE ROSE THE POISON TREE AND THE CINNAMON MINGLE THEIR BOUGHS',
#   'text': 'THE THORN GROWS WITH THE ROSE FE POISON TREE AND THE CINNANON BINGLE THEIW BOUGHS'},
#  {'audio': {'array': array([-0.00405884, -0.00241089,  0.00012207, ..., -0.00244141,
#           -0.0012207 , -0.00152588]),
#    'sampling_rate': 16000},
#   'gold': 'HOW THE FATHER DOTED ON THE SMILES OF THE INFANT',
#   'text': 'HOW THE FATHEW DOTED ON THE SNILES OF THE INFANT'},
#  {'audio': {'array': array([ 4.27246094e-04,  4.88281250e-04,  5.18798828e-04, ...,
#            1.83105469e-04,  9.15527344e-05, -9.15527344e-05]),
#    'sampling_rate': 16000},
#   'gold': 'ARE THE GOLDEN AGE AND DREAM DAYS AM I NOT RIGHT THANK YOU BUT THE BOOK YOU HAVE NOT READ MY BOOK',
#   'text': 'ARE THE GOLDEN AGE AND DLEAN DAYS AM I NOT WIGHT THANK YOU BUT THE BOOK YOU HAVE NOT READ NY BOOK'},
#  {'audio': {'array': array([ 5.49316406e-04,  3.05175781e-04,  2.13623047e-04, ...,
#           -8.85009766e-04, -4.57763672e-04,  3.05175781e-05]),
#    'sampling_rate': 16000},
#   'gold': 'THE DURATION IN OFFICE OF THE EXECUTIVE FROM THE NEW YORK PACKET',
#   'text': 'THE DULATION IN OFFICE OF TE EXECUTIVE FROM DE NEW YORC PACKET'},
#  {'audio': {'array': array([ 0.00372314,  0.0020752 , -0.00222778, ..., -0.00036621,
#           -0.00042725, -0.00024414]),
#    'sampling_rate': 16000},
#   'gold': 'IS THE CHILD OF YOUR THOUGHT',
#   'text': 'IS DE CHILD OF YOUR THOUGHT'},
#  {'audio': {'array': array([-0.00042725, -0.00012207, -0.00067139, ..., -0.00531006,
#           -0.00314331, -0.00427246]),
#    'sampling_rate': 16000},
#   'gold': "AND IF HE DOESN'T LISTEN TO MY ADVICE I AM GOING TO MAKE IT AS UNPLEASANT AS I CAN PRESIDENT WILSON",
#   'text': "AND IF HE DOESN'T LISHTEN TO MY ADVICE I AM GOIN TO MACE IT AZ UNPLEASANT AS I CAN PLESIDENT WILZON"},
#  {'audio': {'array': array([ 0.00012207, -0.00064087, -0.00164795, ...,  0.0319519 ,
#            0.01904297,  0.01858521]),
#    'sampling_rate': 16000},
#   'gold': "THERE WAS GOOD REASON TO STOP AND THINK EVEN FOR THE WORLD'S MOST EMOTIONLESS MAN",
#   'text': "TEWE WAS GOOD REASON TO STOP AND THINK EVEN FOW THE WORLD'Z MOST EMOTIONLESS MAN"},
#  {'audio': {'array': array([-0.00012207,  0.00024414,  0.00018311, ..., -0.00064087,
#           -0.0007019 , -0.00076294]),
#    'sampling_rate': 16000},
#   'gold': 'GLADLY WILL I DO SO ANSWERED PERCEVAL SO THEY WENT TOGETHER TO ARTHUR AND SALUTED HIM',
#   'text': 'GLADLY WILL I DO SO ANSHWEWED PERCEVAL SO TEY WENT TOGETHER TO ARFUR AND ZALUTED HIB'},
#  {'audio': {'array': array([0.00396729, 0.00619507, 0.00402832, ..., 0.00753784, 0.01901245,
#           0.01953125]),
#    'sampling_rate': 16000},
#   'gold': 'ME THEY STRIPPED LIKE A SLAVE THEY LED ME THROUGH THE CITY AND THE PEOPLE MOCKED ME',
#   'text': 'ME THEY ZTRIPPED LIKE A SHLAVE FEY LED BE THROUGH THE CITY AND THE PEOPLE MOCKED ME'},
#  {'audio': {'array': array([-0.00210571, -0.00100708, -0.00125122, ..., -0.01184082,
#           -0.01242065, -0.01391602]),
#    'sampling_rate': 16000},
#   'gold': "AND EVEN MORE CONTEMPTIBLE THAN THAT IS MY MAKING THIS REMARK NOW BUT THAT'S ENOUGH",
#   'text': "AND EVEN BORE CONTEMPTIBLE THAN DAT IS NY BAKING THIS REMARK NOW BUT THAT'S ENOUGH"},
#  {'audio': {'array': array([ 9.76562500e-04,  1.03759766e-03,  1.09863281e-03, ...,
#           -6.10351562e-05, -1.83105469e-04, -2.74658203e-04]),
#    'sampling_rate': 16000},
#   'gold': 'WORTHY FOSTER FATHER WELL WELL',
#   'text': 'WORTHY FOSTER FATHEL WELL WELL'},
#  {'audio': {'array': array([-0.0007019 , -0.00054932, -0.00033569, ..., -0.0043335 ,
#           -0.00448608, -0.00482178]),
#    'sampling_rate': 16000},
#   'gold': 'THE THIRD MAN FROM THE END OH PATTY DID YOU BRING US SOME WEDDING CAKE DID YOU HAVE ANY ADVENTURES',
#   'text': 'THE THIRD MAN FROM THE END OH PATTY DID YOU BRIG US SOBE WEDDING CAKE DID YOU HAVE ANY ADVENTUWESH'},
#  {'audio': {'array': array([-0.00708008, -0.00726318, -0.00650024, ..., -0.00860596,
#           -0.00897217, -0.00921631]),
#    'sampling_rate': 16000},
#   'gold': 'SEVERAL PIPES THAT HAD BEEN EXTINGUISHED WERE LIGHTED AGAIN',
#   'text': 'SEVEWAL PIPES THAT HAD BEEN EXTINUISHED WELE LIGHTED AGAN'},
#  {'audio': {'array': array([ 6.10351562e-05,  9.15527344e-05, -9.15527344e-05, ...,
#            3.96728516e-04,  2.44140625e-04, -3.05175781e-05]),
#    'sampling_rate': 16000},
#   'gold': 'TO A THIRD THE EAST TO A FOURTH THE WEST',
#   'text': 'TO A THIRD DE EAST TO A FOURD THE WEST'},
#  {'audio': {'array': array([-0.00134277, -0.00125122, -0.00134277, ...,  0.00064087,
#            0.0010376 ,  0.00149536]),
#    'sampling_rate': 16000},
#   'gold': 'THE OLD MAN HAD IN THE MEANTIME BEEN PENSIVE BUT ON THE APPEARANCE OF HIS COMPANIONS',
#   'text': 'FE OLD MAN HAD IN THE BEANTIME BEEN PENSIVE BUT ON FE APPEALANCE OF HIS COMPANIONS'},
#  {'audio': {'array': array([0.00195312, 0.00192261, 0.00228882, ..., 0.00244141, 0.00152588,
#           0.00030518]),
#    'sampling_rate': 16000},
#   'gold': 'THE YOUNG WOMAN WHEN SHE OPENED THE DOOR IN THE MORNING',
#   'text': 'THE YOUG WOMAN WHEN SE OPENED FE DOOR IN THE MORNING'},
#  {'audio': {'array': array([-0.00106812, -0.00091553, -0.00079346, ...,  0.00296021,
#            0.00320435,  0.00338745]),
#    'sampling_rate': 16000},
#   'gold': 'AYE AND FOUND IT LIGHTER TOO SOME DAY FOR SURELY SURELY THIS IS NOT THE END',
#   'text': 'AYE AND FOUND IT LIGHTEL TOO SOBE DAY FOR SURELY ZURELY THIS IS NOT DE END'},
#  {'audio': {'array': array([ 0.00558472, -0.01028442, -0.0055542 , ..., -0.00360107,
#           -0.0045166 , -0.00375366]),
#    'sampling_rate': 16000},
#   'gold': 'WHICH WILL PREVENT YOU FROM BEING BURNED UP AND CURE YOU IF YOU CHANCE TO BE A LITTLE SCORCHED',
#   'text': 'WHICH WILL PLEVENT YOU FLOM BEING BURNED UP AND CURE YOU IF YOU CHANCE TO BE A LITTLE SHCORCHED'},
#  {'audio': {'array': array([-0.00344849, -0.00610352, -0.00930786, ..., -0.00823975,
#            0.00250244,  0.00985718]),
#    'sampling_rate': 16000},
#   'gold': 'I WAS ENTIRELY WITHOUT FRIENDS NAY EVEN SO MUCH AS WITHOUT ACQUAINTANCE',
#   'text': 'I WAS ENTIRELY WITHOUT FLIENDSH NAY EVEN SO MUCH AS WITHOUT ACQUAINTANCE'},
#  {'audio': {'array': array([-0.00506592, -0.00042725,  0.00390625, ..., -0.00448608,
#            0.00177002,  0.00061035]),
#    'sampling_rate': 16000},
#   'gold': 'HE MOVED A LITTLE AND SUDDENLY THERE WAS A RINGING IN HIS EARS',
#   'text': 'HE MOVED A LITTLE AND SUDDENLY DELE WASH A RINGING IN HIS EARS'},
#  {'audio': {'array': array([-0.00082397, -0.00057983,  0.00024414, ..., -0.00180054,
#           -0.00161743, -0.00177002]),
#    'sampling_rate': 16000},
#   'gold': 'ONE WOULD DROP INTO THE BOAT WE SOON DISCOVERED SOME INDIANS FOLLOWING THE SCHOOL',
#   'text': 'ONE WOULD DROP INTO THE BOAT WE SOON DISHCOVERED SHOME INDIANS FOLLOWING THE SSHOOL'},
#  {'audio': {'array': array([-3.05175781e-05, -3.05175781e-05, -3.05175781e-05, ...,
#            0.00000000e+00,  0.00000000e+00,  3.05175781e-05]),
#    'sampling_rate': 16000},
#   'gold': 'OUTWARD FORMS AND SYMBOLS MUST BE USED TO CONVEY INTELLECTUAL CONCEPTIONS',
#   'text': 'FORMS AND SYMBOLS MUST BE USED TO CONVEY INTELLECTUAL CONCEPTIONS'},
#  {'audio': {'array': array([-0.00143433, -0.00167847, -0.00161743, ...,  0.00015259,
#           -0.00079346, -0.00100708]),
#    'sampling_rate': 16000},
#   'gold': 'TURNING TO HIS SECRETARY OF STATE HE SAID TO EXPLAIN HIS HESITATION',
#   'text': 'TO HIS ZECRETARY OF STATE HE SHAID TO EXPLAIN HIS HESHITATION'},
#  {'audio': {'array': array([1.22070312e-04, 1.52587891e-04, 9.15527344e-05, ...,
#           5.49316406e-04, 9.76562500e-04, 4.27246094e-04]),
#    'sampling_rate': 16000},
#   'gold': 'LAWYER WATSON AND UNCLE JOHN WERE THERE LOOKING AS GRAVE AS THE IMPORTANT OCCASION DEMANDED',
#   'text': 'WATSHON AND UNCLE JOHN WERE THERE LOOKING AZ GRAVE AS THE IMPORTANT OCCASION DEMANDED'},
#  {'audio': {'array': array([-0.00024414, -0.00054932, -0.00137329, ..., -0.00204468,
#           -0.00164795, -0.00244141]),
#    'sampling_rate': 16000},
#   'gold': 'SHALMANESER THE THIRD OF ASSYRIA FOUND IT NECESSARY TO INVADE BABYLONIA',
#   'text': 'THE THILD OF ASSYRIA FOUND IT NECESSAWY TO INVADE BABYLONIA'},
#  {'audio': {'array': array([-0.00186157, -0.00186157, -0.00164795, ..., -0.00115967,
#           -0.00140381, -0.00109863]),
#    'sampling_rate': 16000},
#   'gold': 'TWENTIETH ROW SEAMED MAKE ONE AT THE BEGINNING TWENTY FIRST ROW SAME AS ELEVENTH',
#   'text': 'ROW SHEAMED MAKE ONE AT TE BEGINNING TWENTY FIWST ROW SAME ASH ELEVENTH'},
#  {'audio': {'array': array([-0.00384521, -0.00485229, -0.00427246, ..., -0.00054932,
#            0.00024414, -0.00231934]),
#    'sampling_rate': 16000},
#   'gold': 'BEYOND THE SOUTHERN BOUNDARY OF THE TERRITORY GASHED BY STUPENDOUS CANYONS',
#   'text': 'THE SOUTHERN BOUNDARY OF THE TERRITOWY GASHED BY STUPENDOUZ CANYONS'},
#  {'audio': {'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           -3.05175781e-05,  0.00000000e+00,  0.00000000e+00]),
#    'sampling_rate': 16000},
#   'gold': 'WITHIN A FEW MINUTES THEIR RUNNING FOOTSTEPS HAD DIED AWAY IN THE DISTANCE',
#   'text': 'A FEW MINUTES THEIR RUNNIN FOOTSTEPS HAD DIED AWAY IN THE DISTANCE'},
#  {'audio': {'array': array([-0.00125122, -0.00143433, -0.0015564 , ..., -0.0027771 ,
#           -0.00219727, -0.00146484]),
#    'sampling_rate': 16000},
#   'gold': 'FETNAH THEN SAID LET US BLESS HEAVEN FOR HAVING BROUGHT US ALL TOGETHER',
#   'text': 'THEN SAID LET US BLESHSH HEAVEN FOW HAVING BLOUGHT US ALL TOGETHER'},
#  {'audio': {'array': array([0.00234985, 0.00299072, 0.00283813, ..., 0.01358032, 0.01309204,
#           0.0135498 ]),
#    'sampling_rate': 16000},
#   'gold': 'RUSSEN AND FAIR PULLING LYON RILEY CHESHIRE AND LESLY WITH MUSKETS AND JOHN REX IN THE STERN SHEETS',
#   'text': 'AND FAIW PULLING LYON RILEY CHESHIWE AND LESLY WITH MUZKETS AND JOHN REX IN THE STERN SHEETS'},
#  {'audio': {'array': array([ 6.10351562e-05,  9.15527344e-05, -1.52587891e-03, ...,
#            3.96728516e-04,  7.62939453e-04,  5.18798828e-04]),
#    'sampling_rate': 16000},
#   'gold': 'LOOKED AWAY AS SOON AS POSSIBLE',
#   'text': 'AWAY AS SOON AS POSSIBLE'},
#  {'audio': {'array': array([0.04263306, 0.04196167, 0.03994751, ..., 0.07168579, 0.07287598,
#           0.07406616]),
#    'sampling_rate': 16000},
#   'gold': 'MARIANNE LOOKED WITH AMAZEMENT AT EDWARD WITH COMPASSION AT HER SISTER',
#   'text': 'LOOKED WITH AMAZEMENT AT EDWARD WID COMPAZSION AT HER SISTER'},
#  {'audio': {'array': array([9.15527344e-05, 1.22070312e-04, 9.15527344e-05, ...,
#           1.00708008e-03, 9.46044922e-04, 8.54492188e-04]),
#    'sampling_rate': 16000},
#   'gold': 'SURELY LUCK HAS BROUGHT US ALSO TO A NEW COUNTRY',
#   'text': 'SURELY LUCK HAS BROUGHT US ALSO TO A NEW'},
#  {'audio': {'array': array([-0.03598022, -0.03726196, -0.03890991, ...,  0.00866699,
#            0.0072937 ,  0.00604248]),
#    'sampling_rate': 16000},
#   'gold': 'INVINCIBLE JEALOUSY AND HATE INVOLUNTARY THRILL OF GRATIFIED VANITY INVOLVED IN PROFOUND UNCERTAINTY',
#   'text': 'INVINCIBLE JEALOUSY AND HATE INVOLUNTARY THRILL OF GRATIFIED VANITY INVOLVED IN PROFOUND'},
#  {'audio': {'array': array([0.00018311, 0.00015259, 0.00027466, ..., 0.0020752 , 0.00222778,
#           0.00241089]),
#    'sampling_rate': 16000},
#   'gold': 'OTHERS WISH HIM TO BE CHOSEN BY THE DECEASED OR ASSUMED BY THE LAW TO BE SO CHOSEN',
#   'text': 'OTHERS WISH HIM TO BE JOSEN BY THE DECEASED OR ASSHUMED BY THE LAW TO BE SO'},
#  {'audio': {'array': array([-0.00634766, -0.00735474, -0.00637817, ..., -0.00131226,
#            0.0039978 ,  0.00500488]),
#    'sampling_rate': 16000},
#   'gold': 'STOCKINGS HAD TO BE DRAWN OFF VIOLENTLY BY ANOTHER PERSON',
#   'text': 'STOCKIGS HAD TO BE DRAWN OFF VIOLENTLY BY ANOTHEL'},
#  {'audio': {'array': array([ 0.00192261,  0.00335693,  0.00265503, ..., -0.00088501,
#            0.00061035,  0.00076294]),
#    'sampling_rate': 16000},
#   'gold': "THOUGH THERE'S SOME ON IT AS ONE'S NO NEED TO SEE THE SMELL'S ENOUGH",
#   'text': "THOUGH THELE'S SHONE ON IT AS ONE'S NO NEED TO SHEE FE SMELL'S"},
#  {'audio': {'array': array([ 0.00079346,  0.00036621,  0.00067139, ..., -0.00033569,
#           -0.00061035, -0.00143433]),
#    'sampling_rate': 16000},
#   'gold': 'SERVING AS A SAFE DEPOSITORY OF THE ARTICLES MENTIONED TO DANTES',
#   'text': 'SERVING AS A SAFE DEPOSITOWY OF THE ARTICLES MENTIONED TO'},
#  {'audio': {'array': array([0.0045166 , 0.00448608, 0.00393677, ..., 0.00189209, 0.0020752 ,
#           0.00228882]),
#    'sampling_rate': 16000},
#   'gold': 'CARBINEER IF THE SAME TO YOU MASTER SAID THE OTHER QUIETLY I NEVER SERVED IN THE INFANTRY',
#   'text': 'CARBINEER IF THE ZAME TO YOU MASTER SAID THE OTHER QUIETLY I NEVEL SERVED IN THE'},
#  {'audio': {'array': array([-9.15527344e-04, -1.19018555e-03, -1.06811523e-03, ...,
#           -6.10351562e-05,  2.74658203e-04,  9.15527344e-05]),
#    'sampling_rate': 16000},
#   'gold': 'JACKSON WHAT TIME DID MISTER WOODS GET OUT HERE ON THE EVENING MISTER FELDERSON WAS KILLED',
#   'text': 'JACKSON WHAT TIME DID MISHTER WOODS GET OUT HERE ON THE EVENING MISTER FELDERSON WAZ'},
#  {'audio': {'array': array([ 0.00317383,  0.00137329, -0.00064087, ...,  0.00064087,
#            0.00039673,  0.00039673]),
#    'sampling_rate': 16000},
#   'gold': 'CHAMBERS WHICH ON ONE MELANCHOLY OCCASION DID BECOME ABSOLUTELY SUICIDAL',
#   'text': 'CHANBERS WHICH ON ONE MELANCHOLY OCCASION DID BECOME ABSOLUTELY'},
#  {'audio': {'array': array([-0.00274658, -0.00439453, -0.00161743, ...,  0.00494385,
#            0.00314331,  0.00244141]),
#    'sampling_rate': 16000},
#   'gold': 'NEITHER HER FATHER NOR MISTER ALLEN DID SO IT WAS CERTAINLY VERY PROVOKING',
#   'text': 'HER FADER NOW NISTER ALLEN DID SO IT WAS CERTAINLY VERY'},
#  {'audio': {'array': array([-3.05175781e-05, -3.05175781e-05,  0.00000000e+00, ...,
#            0.00000000e+00,  3.05175781e-05,  0.00000000e+00]),
#    'sampling_rate': 16000},
#   'gold': 'SKELETONS THEY WERE AND NO HUMAN BEINGS AT ALL HER FATHER',
#   'text': 'THEY WERE AND NO HUMAN BEINGSH AT ALL HER'},
#  {'audio': {'array': array([ 0.00170898,  0.00521851,  0.00369263, ..., -0.00234985,
#           -0.00152588, -0.00100708]),
#    'sampling_rate': 16000},
#   'gold': 'EXPOSING THE CROWN ALTHOUGH THEIR CONCORD HAD ONLY EVIL AS ITS RESULT',
#   'text': 'THE CROWN ALDOUGH FEIR CONCORD HAD ONLY EVIL AS ITSH'},
#  {'audio': {'array': array([-0.00238037, -0.0007019 ,  0.00137329, ...,  0.00134277,
#            0.00036621,  0.0010376 ]),
#    'sampling_rate': 16000},
#   'gold': "RETURN'D WITH A HEART OVERWHELM'D WITH DESPAIR TO THE COURT OF BABYLON",
#   'text': "WIT A HEART OVERWHELM'D WITH DEZPAIR TO THE COURT OF"},
#  {'audio': {'array': array([-0.01126099, -0.01113892, -0.01037598, ...,  0.01251221,
#            0.01229858,  0.01296997]),
#    'sampling_rate': 16000},
#   'gold': 'TENAYA INQUIRED WHAT WAS THE OBJECT OF TAKING ALL THE INDIANS TO THE SAN JOAQUIN PLAIN MY PEOPLE',
#   'text': 'INQUIRED WHAT WAS THE OBJECT OF TAKING ALL DE INDIANS TO THE SAN JOAQUIN PLAIN MY'}]
